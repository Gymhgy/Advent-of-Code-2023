#.#.......#.#.....#.#.#.......#...#.....#...#.#.#...#.#.#.>.>.#...#.#.....#...#...#.###.....#.#.#...#...#.......#...###...#...#...#.....#.#.#
#.#.#####.#.#.#####.#.#######.###.#.#########.#.###.#.#.#.#######.#.#########.#.#.#.###.#####.#.###.#.#########.#######.#.#########.#####.#.#
#.#.#.....#.#.#...#.#...#...#.#...#...#.......#.#...#.#.#...#.....#.........#.#.#.#...#...#...#.#...#...#...#...#.......#...........#...#.#.#
#.#.#.#####.#.#.#.#.###.#.#.#.#.#####.#.#######.#.###.#.###.#.#############.#.#.#.###.###.#.###.#.#####.#.#.#.###.###################.#.#.#.#
#...#.......#...#...###...#...#.......#.........#.....#.....#...............#...#.....###...###...#####...#...###.....................#...#.#
###########################################################################################################################################.#"""

# %%
m=s.split()

st=(0,1)
end = (len(m)-1, len(m[0])-2)
from collections import deque
dist = {}
q = deque([(st, st)])
dist[st] = 0
while q:
    cur, came_from = q.popleft()
    cd = dist[cur]    
    for r,c in neighbors4(*cur):
        d = 1
        if not (0<=r<len(m) and 0<=c<len(m[0])):
            continue
        if m[r][c] == '#':
            continue
        if (r,c) == came_from:
            continue
        if m[r][c] in '<>v^':
            id = '<>v^'.index(m[r][c])
            r += [0,0,1,-1][id]
            c += [-1,1,0,0][id]
            d+=1
        if (r,c) == cur:
            continue
        dist[(r,c)] = cd + d
        q.append(((r,c), cur))

ans(dist[end])
# Out:
# 2334

# %%
for c in "<>v^":
    s=s.replace(c, '.')
m=s.split()
from collections import Counter
regions = Counter()
rmap = {}
st = (0,1)
end = (len(m)-1, len(m[0])-2)
CUR_REGION = 0
stack = [(st,st,CUR_REGION)]
seen = set()
crosses = []
while stack:
    cur, came_from, cr = stack.pop()
    rcs = set()
    if cur in seen:
        continue
    seen.add(cur)
    for r,c in neighbors4(*cur):
        if not (0<=r<len(m) and 0<=c<len(m[0])):
            continue
        if m[r][c] == '#':
            continue
        if (r,c) == came_from:
            continue
        rcs.add((r,c))

    if len(rcs) == 1:
        r,c = min(rcs)

        rmap[cur] = cr
        regions[cr] += 1
        stack.append(((r,c), cur, cr))

        continue
    for rc in rcs:
        r,c = rc
        stack.append(((r,c), cur, CUR_REGION+1))
        CUR_REGION += 1
    crosses.append(cur)

region_crosses = {r: [] for r in regions.keys()}
cross_regions = {cross: set() for cross in crosses}
for cross in crosses:
    for r,c in neighbors4(*cross):
        if not (0<=r<len(m) and 0<=c<len(m[0])):
            continue
        if m[r][c] == '#':
            continue
        id = rmap[(r,c)]
        region_crosses[id].append(cross)
        cross_regions[cross].add(id)
        

st_cross = region_crosses[0][0]
end_cross = end
stack = [(st_cross, [], regions[0])]
longest = 0
while stack:
    cross, visited, dist = stack.pop()
    if cross == end_cross:
        longest = max(longest, dist)
        continue
    for region in cross_regions[cross]:
        for adj in region_crosses[region]:
            if adj in visited or adj == cross: continue
            stack.append((adj, visited + [cross], dist + 1 + regions[region]))
longest
# Out:
# 6422

# %%
#PART 2 Visualized
for c in "<>v^":
    s=s.replace(c, '.')
m=s.split()
regions = []
rmap = {}
st = (0,1)
end = (len(m)-1, len(m[0])-2)
stack = [(st,st,[])]
seen = set()
crosses = []
while stack:
    cur, came_from, cr = stack.pop()
    rcs = set()
    if cur in seen:
        if cr:
            regions.append(cr)
        continue
    seen.add(cur)
    for r,c in neighbors4(*cur):
        if not (0<=r<len(m) and 0<=c<len(m[0])):
            continue
        if m[r][c] == '#':
            continue
        if (r,c) == came_from:
            continue
        rcs.add((r,c))

    if len(rcs) == 1:
        r,c = min(rcs)

        rmap[cur] = cr
        cr.append(cur)
        stack.append(((r,c), cur, cr))

        continue
    for rc in rcs:
        r,c = rc
        stack.append(((r,c), cur, []))
    regions.append(cr)
    crosses.append(cur)
CEND      = '\33[0m'
CREDBG    = '\33[41m'
CGREENBG  = '\33[42m'
CYELLOWBG = '\33[43m'
CBLUEBG   = '\33[44m'
CVIOLETBG = '\33[45m'
CBEIGEBG  = '\33[46m'
CWHITEBG  = '\33[47m'
CGREY    = '\33[90m'
CRED2    = '\33[91m'
CGREEN2  = '\33[92m'
CYELLOW2 = '\33[93m'
CBLUE2   = '\33[94m'
CVIOLET2 = '\33[95m'
CBEIGE2  = '\33[96m'
CWHITE2  = '\33[97m'
colors = [CREDBG   ,CGREENBG ,CYELLOWBG,CBLUEBG  ,CVIOLETBG,CBEIGEBG ,CWHITEBG ,CGREY   ,CRED2   ,CGREEN2 ,CYELLOW2,CBLUE2  ,CVIOLET2,CBEIGE2 ,CWHITE2]
t = [[0]*len(l) for l in s.split()]
for i, rs in enumerate(regions):
    for r,c in rs:
        t[r][c] = colors[i%len(colors)]+'ABCDEFGHIJKLMNOPQRSTUVWXYZABCDEFGHIJKLMNOPQRSTUVWXYZABCDEFGHIJKLMNOPQRSTUVWXYZABCDEFGHIJKLMNOPQRSTUVWXYZ'[i]+CEND
print('\n'.join(''.join(str(t[i][j] or m[i][j]) for j,c in enumerate(l)) for i,l in enumerate(t)))
# Out:
# #A###########################################################################################################################################
# #A#####AAAAAAAAAAAAAAAAAAAAA#HHHHHHHHHHHHH#HHHHHHH#HHH#III###III###IIIII#IIIIIII#SSS###SSS#SSS#SSSSS#RRRRRRRRRRRRRRR#RRR#RRRRRRRRR#RRR#RRR###
# #A#####A###################A#H###########H#H#####H#H#H#I#I###I#I###I###I#I#####I#S#S###S#S#S#S#S###S#R#############R#R#R#R#######R#R#R#R#R###
# #AAA###A#AAA#AAAAAAAAAAAAAAA#HHHHHHHHHHH#H#H#HHHHH#H#H#I#I###I#I#III#III#III#III#S#S#SSS#SSS#S#SSS#S#RRRRR#RRRRRRRRR#R#RRR#RRRRR#R#R#R#R#R###
# ###A###A#A#A#A#########################H#H#H#H#####H#H#I#I###I#I#I###I#####I#I###S#S#S#######S###S#S#####R#R#########R#####R###R#R#R#R#R#R###
# ###AAAAA#A#A#AAAAAAA###HHH#HHH#HHH#HHH#H#H#H#HHHHHHH#H#I#III#I#I#III#III#III#III#S#S#SSSSSSS#S#SSS#SS.RRRR#RRRRR#RRR#RRRRR#RRR#RRR#R#R#R#R###
# ...
